# %% [markdown]
# <a href="https://colab.research.google.com/github/NehaKumari500092077/Bird-Species-Identification/blob/main/try.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import librosa
import librosa.display as display
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks
# %matplotlib inline
from pathlib import Path
import numpy, scipy, matplotlib.pyplot as plt, sklearn, urllib, IPython.display as ipd
import librosa, librosa.display
import warnings

#draw waveform using librosa
fig = plt.figure(figsize=(14,5))
ax = fig.subplots()

ts, sr = librosa.load("/content/sample_data/Babbler1010.wav")
print(ts.shape)
display.waveshow(ts, sr,x_axis='time')
ax.hlines(y=0, color='red', xmin=0, xmax=30)
peak = find_peaks(ts, height=0.01)
print(peak)

plt.figure(figsize=(14, 5))
librosa.display.waveplot(ts, sr=sr)



#print("x-axis of -",peak[1]['peak_heights'][0]," is ",ts[peak[1]['peak_heights'][0]])
#ax.scatter(peak[0], peak[1]['peak_heights'], color = 'green', s = 20, marker = 'X', label = 'Maxima')



#draw waveform using matplot
#fig = plt.figure(figsize=(14,5))
#ax = fig.subplots()
#plt.plot(ts)
#plt.xlabel("time [ms]")
#plt.ylabel("Amplitude")
#ax.hlines(y=0, color='red', xmin=0, xmax=600000)
#plt.savefig("output.jpg")
#ax.scatter(peak[0], peak[1]['peak_heights'], color = 'r', s = 20, marker = 'X', label = 'Maxima')
# Out:
# (612435,)
# (array([ 12110,  12148,  12157, ..., 611006, 611010, 611023]), {'peak_heights': array([0.01028484, 0.01100364, 0.01114748, ..., 0.01098547, 0.01049686,
#        0.01035813])})
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-87606707a810> in <module>()
#      27 warnings.filterwarnings("ignore")
#      28 signals = [
# ---> 29     librosa.load(p)[0] for p in Path()('/content/sample_data/Babbler10.mp3')
#      30 ]
#      31
#
# TypeError: 'PosixPath' object is not callable

# %%
import librosa
import librosa.display as display
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks
from scipy import signal
# %matplotlib inline
from pathlib import Path
import numpy, scipy, matplotlib.pyplot as plt, sklearn, urllib, IPython.display as ipd
import librosa, librosa.display
import warnings
import peakutils
from peakutils.plot import plot as pplot
import peakdetect
import wave
from scipy.io.wavfile import read

#draw waveform using librosa
fig = plt.figure(figsize=(14,5))
ax = fig.subplots()

ts, sr = librosa.load("/content/sample_data/Babbler1010.wav")
wav_obj = wave.open('/content/sample_data/Babbler1010.wav', 'rb')
samplerate, data = read('/content/sample_data/Babbler1010.wav')
display.waveshow(ts, sr,x_axis='time',marker='o')
ax.hlines(y=0, color='red', xmin=0, xmax=30)
peak = find_peaks(ts, height=0.01)
duration = len(data)/22050
time = np.arange(0,duration,1/22050)
print(time.shape)


audio='arabic6'
fig2 = plt.figure(figsize=(14,5))
y, sr1 = librosa.load('/content/sample_data/Babbler1010.wav'.format(audio))
time2 = np.arange(0,len(y))/sr1
ax2 = fig2.subplots()
ax2.plot(time2,y)
ax2.set(xlabel='Time(s)',ylabel='sound amplitude')
plt.show()

o_env2 = librosa.onset.onset_strength(y, sr=sr1)
times2 = librosa.frames_to_time(np.arange(len(o_env2)), sr=sr1)
plt.plot(times2, o_env2,marker = 'o', mec = 'r',mfc = 'r', label='Onset strength')
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.show()
indexes = peakutils.indexes(o_env2, thres=0.0, min_dist=0)
#print(indexes)
#print(time2[indexes], y[indexes])
plt.figure(figsize=(10,6))
pplot(times2, o_env2, indexes)
plt.title('Second estimate')

#sample_freq = wav_obj.getframerate()
#n_samples = wav_obj.getnframes()
#t_audio = n_samples/sample_freq
#n_channels = wav_obj.getnchannels()
#signal_wave = wav_obj.readframes(-1)
#signal_array = np.frombuffer(signal_wave, dtype=np.int16)
#l_channel = signal_array[0::2]
#r_channel = signal_array[1::2]
#times = np.linspace(0, len(signal_wave)/sample_freq, num = len(signal_wave))
#plt.figure(figsize=(15, 5))
#print(time2.shape)
#print(y.shape)
#print(l_channel.shape)
#plt.plot(time2, r_channel)
#plt.title('Left Channel')
#plt.ylabel('Signal Value')
#plt.xlabel('Time (s)')
#plt.xlim(0, t_audio)
#plt.show()


#onset_frames1 = librosa.onset.onset_detect(ts, sr=sr, wait=1, pre_avg=1, post_avg=1, pre_max=1, 
#post_max=1)
#print(onset_frames1)
#onset_times = librosa.frames_to_time(onset_frames1)
o_env1 = librosa.onset.onset_strength(ts, sr=sr)
times1 = librosa.frames_to_time(np.arange(len(o_env1)), sr=sr)
#onset_frames1 = librosa.util.peak_pick(o_env1, 10, 10, 10, 10, 2, 60)
#print(onset_frames1)

#D = np.abs(librosa.stft(ts))
plt.figure(figsize=(14,5))
#ax1 = plt.subplot(2, 1, 1)
#librosa.display.specshow(librosa.amplitude_to_db(D, ref=np.max),
#x_axis='time', y_axis='log')
#plt.title('Power spectrogram')
#plt.subplot(2, 1, 2, sharex=ax1)

plt.plot(times1, o_env1,marker = 'o', mec = 'r',mfc = 'r', label='Onset strength')
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
#plt.vlines(times1[onset_frames1], 0, o_env1.max(), color='r', alpha=0.9, linestyle='--', 
#label='Onsets')
#plt.axis('tight')
#plt.legend(frameon=True, framealpha=0.75)
plt.show()
#print(onset_times)

indexes = peakutils.indexes(o_env1, thres=0.0, min_dist=0)
#print(indexes)
#print(times1[indexes], o_env1[indexes])
plt.figure(figsize=(10,6))
pplot(times1, o_env1, indexes)
plt.title('First estimate')

#print(frames)
#print(peak)
#print(times1)
#print(o_env1)



#o_env = librosa.onset.onset_strength(ts, sr=sr)
#print(o_env)
#times = librosa.times_like(o_env, sr)
#print(times)
#onset_frames = librosa.onset.onset_detect(o_env,sr)
#print(onset_frames) 

#fig, ax = plt.subplots(nrows=2, sharex=True, figsize=(15,9))
#librosa.display.specshow(ts, x_axis='time', y_axis='log', ax=ax[0])

#ax[0].set(title='Power spectrogram')
#ax[0].label_outer()
#ax[1].plot(times, o_env, label='Onset strength')
#ax[1].vlines(times[onset_frames], 0, o_env.max(), 
#             color='r', alpha=0.9,
#             linestyle='--', label='Onsets')
#ax[1].legend()

#plt.savefig('onsets.png')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: WavFileWarning: Chunk (non-data) not understood, skipping it.
# (1224870,)
# Text(0.5, 1.0, 'First estimate')

# %%
pip install peakutils
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import matplotlib.pyplot as plt
from scipy.misc import electrocardiogram
from scipy.signal import find_peaks
import numpy as np

x = electrocardiogram()[2000:4000]
peaks, _ = find_peaks(x, height=0)
plt.plot(x)
plt.plot(peaks, x[peaks], "x")
plt.plot(np.zeros_like(x), "--", color="gray")
plt.show()
